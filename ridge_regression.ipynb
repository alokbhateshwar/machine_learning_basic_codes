# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes()
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
x=data.data
y=data.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
#first we do with linearRegression for the comparision 
from sklearn.linear_model import  LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediciton1= lr.predict(x_test)
print(prediciton1)
# Out:
# [202.97393433 137.93621153  78.71964577 155.63591567 191.88954313
#   65.39476239 124.67994268 248.32719288  55.2128402  230.5915986
#  164.20388857 136.05686586 173.01026467 222.44438812  55.16982452
#   75.34051376 132.47688194 184.7020575  196.35502278  82.40221854
#  145.0646955   97.05749732 181.23763813 172.59786394 119.52303692
#   46.99476931 194.01572881 168.63591854 209.59887022  86.51525281
#  146.98295242 101.48722694 136.41306906 149.12019044  22.0159211
#   61.28198584 189.46850058 219.43927464  94.87884183  78.92158114
#  176.74941176 120.95202161 155.72115804 190.64414742  53.39579215
#  105.18187535 116.14005983 166.52526126 175.66482925 294.76512638
#  252.04240615  24.40992769 101.75664327 223.70740786 242.09915388
#  238.86880621 153.79827854 228.73797593 111.98468708  82.05819817
#  136.32191467 120.30080848 262.86833066  80.54559239 146.96847771
#  218.261075    36.97509839 234.91729886 153.65403109 254.69894702
# ...

# %%
from sklearn.metrics import  r2_score,mean_squared_error
print("R2_Score is :",r2_score(y_test,prediciton1))
print("Root Mean Squre Error:",np.sqrt(mean_squared_error(y_test,prediciton1)))
# Out:
# R2_Score is : 0.5501693804192853
# Root Mean Squre Error: 54.02014014892232

# %%
#now we done this with Ridge 
from sklearn.linear_model import  Ridge
r=Ridge(alpha=0.001)
r.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
prediciton2 = r.predict(x_test)

# %%
print(prediciton2)
# Out:
# [202.80631487 138.29775313  77.46365475 155.63837607 191.61417315
#   65.21469896 124.8822509  251.17618363  54.0759622  230.38409464
#  163.77634184 135.99159654 173.51816024 221.41314579  56.85033787
#   75.70897547 131.69537943 184.04573944 195.78669856  82.46556343
#  144.66280559  97.33551223 181.4983708  172.88182121 119.41183932
#   49.16207338 193.80853497 168.05367537 209.15803878  86.7778345
#  146.26243117 101.61925053 136.05677331 148.87452499  24.92615921
#   62.15260071 189.12466858 218.98487466  94.74463656  80.06337799
#  176.35179002 120.54888213 155.13005373 190.92461469  54.21355871
#  104.73371092 115.63150554 166.82457019 175.1627671  296.13890823
#  250.95762781  25.63879909 101.83457568 223.45573737 241.80121315
#  238.40810451 154.63283672 229.40240612 111.60713938  82.84975234
#  136.174707   120.33946704 262.36897628  80.57426299 146.3798479
#  218.10837643  38.80409261 234.44737006 153.41087767 254.37829705
# ...

# %%
from sklearn.metrics import  r2_score,mean_squared_error
print("R2_Score is :",r2_score(y_test,prediciton2))
print("Root Mean Squre Error:",np.sqrt(mean_squared_error(y_test,prediciton2)))
# Out:
# R2_Score is : 0.5512300382695001
# Root Mean Squre Error: 53.95641538425093

# %%
#dont use it because of overfiting 
best_r2 =-1.0
for i in range(1000):
    ri = Ridge(alpha=i)
    ri.fit(x_train,y_train)
    y_pred= ri.predict(x_test)
    R2=r2_score(y_test,y_pred)
if R2 > best_r2:
    best_r2 = R2
    alpha = i
    print("the best value of alpha:",alpha)
# Out:
# the best value of alpha: 999
